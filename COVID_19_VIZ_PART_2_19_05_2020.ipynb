# %% [markdown]
# <a href="https://colab.research.google.com/github/SIDDHARTHA2301/COVID-19/blob/master/COVID_19_VIZ_PART_2_19_05_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #NOVEL CORONA VIRUS DATA SETS COMPARISON OF INDIA VS WORLD

# %%
import os
os.environ['KAGGLE_USERNAME'] = "siddharthabose2301" # username from the json file
os.environ['KAGGLE_KEY'] = "088b8c75aec9e4bafbe472fae7e2c06e" # key from the json file
# !kaggle datasets download -d sudalairajkumar/novel-corona-virus-2019-dataset

! unzip novel-corona-virus-2019-dataset.zip
# Out:
# Downloading novel-corona-virus-2019-dataset.zip to /content
#   0% 0.00/1.01M [00:00<?, ?B/s]
# 100% 1.01M/1.01M [00:00<00:00, 67.4MB/s]
# Archive:  novel-corona-virus-2019-dataset.zip
#   inflating: COVID19_line_list_data.csv
#   inflating: COVID19_open_line_list.csv
#   inflating: covid_19_data.csv
#   inflating: time_series_covid_19_confirmed.csv
#   inflating: time_series_covid_19_confirmed_US.csv
#   inflating: time_series_covid_19_deaths.csv
#   inflating: time_series_covid_19_deaths_US.csv
#   inflating: time_series_covid_19_recovered.csv

# %%
import os
os.environ['KAGGLE_USERNAME'] = "siddharthabose2301" # username from the json file
os.environ['KAGGLE_KEY'] = "088b8c75aec9e4bafbe472fae7e2c06e" # key from the json file
# !kaggle datasets download -d sudalairajkumar/covid19-in-india

! unzip covid19-in-india.zip
# Out:
# Downloading covid19-in-india.zip to /content
#   0% 0.00/196k [00:00<?, ?B/s]
# 100% 196k/196k [00:00<00:00, 73.1MB/s]
# Archive:  covid19-in-india.zip
#   inflating: AgeGroupDetails.csv
#   inflating: HospitalBedsIndia.csv
#   inflating: ICMRTestingDetails.csv
#   inflating: ICMRTestingLabs.csv
#   inflating: IndividualDetails.csv
#   inflating: StatewiseTestingDetails.csv
#   inflating: covid_19_india.csv
#   inflating: population_india_census2011.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.dates as mdates

# %%
data = pd.read_csv("covid_19_india.csv")
data.tail()
# Out:
#        Sno      Date     Time  ... Cured Deaths Confirmed
# 2095  2096  19/05/20  8:00 AM  ...  1000     35      1597
# 2096  2097  19/05/20  8:00 AM  ...    85      0       167
# 2097  2098  19/05/20  8:00 AM  ...    52      1        93
# 2098  2099  19/05/20  8:00 AM  ...  2783    118      4605
# 2099  2100  19/05/20  8:00 AM  ...  1006    244      2825
#
# [5 rows x 9 columns]

# %%
data.set_index("Sno",inplace = True)

# %%
data.drop(["Time","ConfirmedIndianNational","ConfirmedForeignNational"],axis = 1,inplace = True)

# %%
data.index.name = ""
#data["Date"] = pd.to_datetime(data["Date"])
#data.sort_values(by = "Date")

# %%
data.head()
# Out:
#        Date State/UnionTerritory  Cured  Deaths  Confirmed
#
# 1  30/01/20               Kerala      0       0          1
# 2  31/01/20               Kerala      0       0          1
# 3  01/02/20               Kerala      0       0          2
# 4  02/02/20               Kerala      0       0          3
# 5  03/02/20               Kerala      0       0          3

# %%
data["Date"] = pd.to_datetime(data["Date"],format = '%d/%m/%y')
data.sort_values(by = "Date")
data.head()
# Out:
#         Date State/UnionTerritory  Cured  Deaths  Confirmed
#
# 1 2020-01-30               Kerala      0       0          1
# 2 2020-01-31               Kerala      0       0          1
# 3 2020-02-01               Kerala      0       0          2
# 4 2020-02-02               Kerala      0       0          3
# 5 2020-02-03               Kerala      0       0          3

# %%
def state_data(statename,dataset):
  return dataset[dataset['State/UnionTerritory']==statename]

# %%
MPdata = state_data('Madhya Pradesh',data)

# %%
MPdata
# Out:
# 2086 2020-05-19       Madhya Pradesh   2435     252       5236

# %%
statewise = data.groupby('State/UnionTerritory').max()

# %%
statewise.drop('Date',axis = 1,inplace = True)

# %%
statewise
# Out:
#                              Cured  Deaths  Confirmed
# State/UnionTerritory
# Andaman and Nicobar Islands     33       0         33
# Andhra Pradesh                1552      50       2474
# Arunachal Pradesh                1       0          1
# Assam                           41       2        107
# Bihar                          494       9       1391
# Chandigarh                      54       3        196
# Chhattisgarh                    59       0         93
# Dadar Nagar Haveli               0       0          1
# Delhi                         4485     168      10054
# Goa                              7       0         38
# Gujarat                       4804     694      11745
# Haryana                        598      14        928
# Himachal Pradesh                44       3         90
# Jammu and Kashmir              609      15       1289
# Jharkhand                      113       3        223
# Jharkhand#                       0       3         45
# Karnataka                      530      37       1246
# Kerala                         497       4        630
# Ladakh                          41       0         43
# Madhya Pradesh                2435     252       5236
# Maharashtra                   8437    1249      35058
# Manipur                          2       0          7
# Meghalaya                       11       1         13
# Mizoram                          1       0          1
# Nagaland                         0       0          1
# Nagaland#                        0       0          0
# Odisha                         220       4        876
# Puducherry                       9       1         18
# Punjab                        1547      37       1980
# Rajasthan                     3218     138       5507
# Tamil Nadu                    4406      81      11760
# Telengana                     1000      35       1597
# Tripura                         85       0        167
# Unassigned                       0       0         77
# Uttar Pradesh                 2783     118       4605
# Uttarakhand                     52       1         93
# West Bengal                   1006     244       2825

# %%
def plot_data(data,statename):
  fig,ax = plt.subplots(figsize=(5,4))
  ax.plot(data['Date'],data['Confirmed'])
  ax.set_title(statename)
  return figure

# %%
fig = plt.figure(figsize=(40,90))

for statenum in range(len(statewise.index)):
    state = statewise.index[statenum]
    statedata = state_data(state,data)
    ax = fig.add_subplot(9,4,statenum+1)
    ax.plot(statedata['Date'],statedata['Confirmed'],lw = 5,color = 'purple')
    ax.plot(statedata['Date'],statedata['Cured'],lw = 5,color = 'green')
    ax.plot(statedata['Date'],statedata['Deaths'],lw = 5,color = 'red')
    ax.xaxis.set_major_locator(mdates.WeekdayLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))
    ax.set_title(state,size = 30)
    ax.tick_params(labelsize=15)

plt.show()
fig.savefig('statewisedata.png')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-3491e739eecd> in <module>()
#       4     state = statewise.index[statenum]
#       5     statedata = state_data(state,data)
# ----> 6     ax = fig.add_subplot(9,4,statenum+1)
#       7     ax.plot(statedata['Date'],statedata['Confirmed'],lw = 5,color = 'purple')
#       8     ax.plot(statedata['Date'],statedata['Cured'],lw = 5,color = 'green')
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1417                     self._axstack.remove(ax)
#    1418
# -> 1419             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1420
#    1421         return self._add_axes_internal(key, a)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      64                 if num < 1 or num > rows*cols:
#      65                     raise ValueError(
# ---> 66                         f"num must be 1 <= num <= {rows*cols}, not {num}")
#      67                 self._subplotspec = GridSpec(
#      68                         rows, cols, figure=self.figure)[int(num) - 1]
#
# ValueError: num must be 1 <= num <= 36, not 37

# %%
statewise
# Out:
#                              Cured  Deaths  Confirmed
# State/UnionTerritory
# Andaman and Nicobar Islands     33       0         33
# Andhra Pradesh                1552      50       2474
# Arunachal Pradesh                1       0          1
# Assam                           41       2        107
# Bihar                          494       9       1391
# Chandigarh                      54       3        196
# Chhattisgarh                    59       0         93
# Dadar Nagar Haveli               0       0          1
# Delhi                         4485     168      10054
# Goa                              7       0         38
# Gujarat                       4804     694      11745
# Haryana                        598      14        928
# Himachal Pradesh                44       3         90
# Jammu and Kashmir              609      15       1289
# Jharkhand                      113       3        223
# Jharkhand#                       0       3         45
# Karnataka                      530      37       1246
# Kerala                         497       4        630
# Ladakh                          41       0         43
# Madhya Pradesh                2435     252       5236
# Maharashtra                   8437    1249      35058
# Manipur                          2       0          7
# Meghalaya                       11       1         13
# Mizoram                          1       0          1
# Nagaland                         0       0          1
# Nagaland#                        0       0          0
# Odisha                         220       4        876
# Puducherry                       9       1         18
# Punjab                        1547      37       1980
# Rajasthan                     3218     138       5507
# Tamil Nadu                    4406      81      11760
# Telengana                     1000      35       1597
# Tripura                         85       0        167
# Unassigned                       0       0         77
# Uttar Pradesh                 2783     118       4605
# Uttarakhand                     52       1         93
# West Bengal                   1006     244       2825

# %%
statewise.drop(['Jharkhand#','Nagaland#'],inplace = True)

# %%
statewise['Death/Confirmed'] = statewise['Deaths']/statewise['Confirmed']

# %%
statewise['Cured/Confirmed'] = statewise['Cured']/statewise['Confirmed']

# %%
statewise['Death/Confirmed'] = statewise['Death/Confirmed']*100
statewise['Cured/Confirmed'] = statewise['Cured/Confirmed']*100

# %%
statewise
# Out:
#                              Cured  Deaths  ...  Death/Confirmed  Cured/Confirmed
# State/UnionTerritory                        ...
# Andaman and Nicobar Islands     33       0  ...         0.000000       100.000000
# Andhra Pradesh                1552      50  ...         2.021019        62.732417
# Arunachal Pradesh                1       0  ...         0.000000       100.000000
# Assam                           41       2  ...         1.869159        38.317757
# Bihar                          494       9  ...         0.647017        35.514019
# Chandigarh                      54       3  ...         1.530612        27.551020
# Chhattisgarh                    59       0  ...         0.000000        63.440860
# Dadar Nagar Haveli               0       0  ...         0.000000         0.000000
# Delhi                         4485     168  ...         1.670977        44.609111
# Goa                              7       0  ...         0.000000        18.421053
# Gujarat                       4804     694  ...         5.908897        40.902512
# Haryana                        598      14  ...         1.508621        64.439655
# Himachal Pradesh                44       3  ...         3.333333        48.888889
# Jammu and Kashmir              609      15  ...         1.163693        47.245927
# Jharkhand                      113       3  ...         1.345291        50.672646
# Karnataka                      530      37  ...         2.969502        42.536116
# Kerala                         497       4  ...         0.634921        78.888889
# Ladakh                          41       0  ...         0.000000        95.348837
# Madhya Pradesh                2435     252  ...         4.812834        46.504966
# Maharashtra                   8437    1249  ...         3.562668        24.065834
# Manipur                          2       0  ...         0.000000        28.571429
# Meghalaya                       11       1  ...         7.692308        84.615385
# Mizoram                          1       0  ...         0.000000       100.000000
# Nagaland                         0       0  ...         0.000000         0.000000
# Odisha                         220       4  ...         0.456621        25.114155
# Puducherry                       9       1  ...         5.555556        50.000000
# Punjab                        1547      37  ...         1.868687        78.131313
# Rajasthan                     3218     138  ...         2.505902        58.434719
# Tamil Nadu                    4406      81  ...         0.688776        37.465986
# Telengana                     1000      35  ...         2.191609        62.617408
# Tripura                         85       0  ...         0.000000        50.898204
# Unassigned                       0       0  ...         0.000000         0.000000
# Uttar Pradesh                 2783     118  ...         2.562432        60.434311
# Uttarakhand                     52       1  ...         1.075269        55.913978
# West Bengal                   1006     244  ...         8.637168        35.610619
#
# [35 rows x 5 columns]

# %%
ax = statewise.plot.bar(y = 'Cured/Confirmed',figsize = (15,7),color = 'green')
for p in ax.patches:
    ax.annotate(str(round(p.get_height(),1)), (p.get_x() * 0.995, p.get_height() + 1.01))
ax.tick_params(labelsize=15)
ax.set_xlabel('State/UT',size = 20)
ax.set_title("Percentage of Patients Cured",size = 30)

plt.savefig('CURED_PERCENTAGE.png',bbox_inches='tight',pad_inches=1)
files.download( "CURED_PERCENTAGE.png" )

# %%
ax = statewise.plot.bar(y = 'Death/Confirmed',figsize = (15,7),color = 'red')
for p in ax.patches:
    ax.annotate(str(round(p.get_height(),1)), (p.get_x() * 0.995, p.get_height() * 1.01))
ax.tick_params(labelsize=15)
ax.set_xlabel('State/UT',size = 20)
ax.set_title("Percentage of Death",size = 30)

plt.savefig('Death_PERCENTAGE.png',bbox_inches='tight',pad_inches=1)
files.download( "Death_PERCENTAGE.png" )
